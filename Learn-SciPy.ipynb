# %%
from scipy.cluster.vq import kmeans,whiten
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style("darkgrid")

# %% [markdown]
# **cluster**

# %%
pts=100
a=np.random.multivariate_normal([0,0],[[4,1],[1,4]],size=pts)
b=np.random.multivariate_normal([30,10],[[10,2],[2,1]],size=pts)
features=np.concatenate((a,b))
whitend=whiten(features)
codebook,distortion=kmeans(whitend,2)

# %%
plt.scatter(whitend[:,0],whitend[:,1])
plt.scatter(codebook[:,0],codebook[:,1],c='r')
plt.show()

# %% [markdown]
# **constant**

# %%
import scipy
from scipy.constants import find

# %%
print("golden ration value ",scipy.constants.golden)
# Out:
# golden ration value  1.618033988749895

# %%
find('boltzmann')
# Out:
# ['Boltzmann constant',
#  'Boltzmann constant in Hz/K',
#  'Boltzmann constant in eV/K',
#  'Boltzmann constant in inverse meter per kelvin',
#  'Stefan-Boltzmann constant']

# %%
scipy.constants.physical_constants['Boltzmann constant in inverse meter per kelvin']
# Out:
# (69.50348004, 'm^-1 K^-1', 0.0)

# %% [markdown]
# **FFT (Fast Fourier Transformation)**

# %%
fre=10
fre_samp=100

t=np.linspace(0,2,2*fre_samp,endpoint=False)
a=np.sin(fre*2*np.pi*t)

plt.plot(t,a)
plt.xlabel('time (s)')
plt.ylabel("sginal amplitude")
plt.show()

# %%
from scipy import fftpack

A=fftpack.fft(a)
frequency=fftpack.fftfreq(len(a))*fre_samp

plt.stem(frequency,np.abs(A))
plt.xlabel('frequency in hz')
plt.ylabel("frequency spectrum magnitude")
plt.show()

# %% [markdown]
# **interpolation**

# %%
x=np.linspace(0,5,10)
y=np.cos(x**2/3+4)
y

plt.scatter(x,y,c='r')
plt.show()

# %%
from scipy.interpolate import interp1d

# %%
f1=interp1d(x,y,kind='linear')
f2=interp1d(x,y,kind='cubic')

xnew=np.linspace(0,4,30)

plt.plot(x,y,'o',xnew,f1(xnew),'-',xnew,f2(xnew),'--')
plt.legend(['data','cubic','nearest'],loc='best')
plt.show()

# %% [markdown]
# **linalg (linear algebra)**

# %%
import numpy as np 
from scipy import linalg

# x+2y-3z=-3
# 2x-5y+4z=13
# 5x+4y-z=5

# creating input array
a=np.array([[1,2,-3],[2,-5,4],[5,4,-1]])

# solution array
b=np.array([[-3],[13],[5]])

# solve linear algebra
x=linalg.solve(a,b)

print(x)

print('check the result')
print(a.dot(x)-b)
# Out:
# [[ 2.]
#  [-1.]
#  [ 1.]]
# check the result
# [[0.]
#  [0.]
#  [0.]]

# %%
x1=linalg.det(a)
print(a,x1)
# Out:
# [[ 1  2 -3]
#  [ 2 -5  4]
#  [ 5  4 -1]] -66.00000000000001

# %% [markdown]
# ***Ndimage***

# %%
import scipy.misc

face=scipy.misc.face()

plt.imshow(face)
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_15560\1545647636.py:3: DeprecationWarning: scipy.misc.face has been deprecated in SciPy v1.10.0; and will be completely removed in SciPy v1.12.0. Dataset methods have moved into the scipy.datasets module. Use scipy.datasets.face instead.
#   face=scipy.misc.face()

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
lx,ly,channels=face.shape
crop_face=face[int(lx/4):int(-lx/4),int(ly/4):int(-ly/4)]
plt.imshow(crop_face)
plt.show()
